# %%
import matplotlib.pyplot as plt
import os
import numpy as np
import matplotlib
import nibabel as nib

# %%
def find_highest_variance_time_points(img_data, num_points=5):
    """
    Identify time points with the highest variance in 4D PET scan data.

    Parameters:
    - img_data: 4D numpy array of the PET scan data.
    - num_points: Number of time points to select based on highest variance.

    Returns:
    - top_variance_time_points: Indices of time points with the highest variance.
    """
    variance_list = []
    for time_point in range(img_data.shape[-1]):
        time_point_data = img_data[..., time_point]
        variance_list.append(np.var(time_point_data))

    # Get indices of the top `num_points` variances
    top_variance_indices = np.argsort(variance_list)[-num_points:]
    # get lowest variance
    # top_variance_indices = np.argsort(variance_list)[:num_points]

    # Sort the indices to maintain the temporal order
    top_variance_time_points = sorted(top_variance_indices)
    
    # Optionally, print the variance values for the selected time points
    # for idx in top_variance_time_points:
    #     print(f"Time point {idx} has variance: {variance_list[idx]}")

    return top_variance_time_points

# %%
def guess_orientation_and_extract_all_slices(img_data):

    # Guess orientations based on dimensions
    dimensions = img_data.shape
    sorted_dims = np.argsort(dimensions)  # Ascending order of dimensions
    
    # Assuming the smallest dimension is Sagittal, next is Coronal, and largest is Axial
    if len(sorted_dims) == 3:
        sagittal_index, coronal_index, axial_index = sorted_dims
    else:
        sagittal_index, coronal_index, axial_index, fourth_index = sorted_dims
    
    # Initialize dictionaries to hold all slices for each orientation
    sagittal_slices = {}
    coronal_slices = {}
    axial_slices = {}
    
    # Extract all slices for each orientation
    for i in range(dimensions[sagittal_index]):
        sagittal_slices[i] = img_data.take(i, axis=sagittal_index)
    for i in range(dimensions[coronal_index]):
        coronal_slices[i] = img_data.take(i, axis=coronal_index)
    for i in range(dimensions[axial_index]):
        axial_slices[i] = img_data.take(i, axis=axial_index)
    
    return {'Sagittal': sagittal_slices, 'Coronal': coronal_slices, 'Axial': axial_slices}

# %%
def extract_all_slices_optimized(img_data):
    """
    Optimized function to extract all slices from a 3D or 4D PET scan data in Sagittal, Coronal, and Axial orientations.

    Parameters:
    - img_data: 3D or 4D numpy array of the PET scan data.

    Returns:
    A dictionary containing all slices for Sagittal, Coronal, and Axial orientations.
    """
    # print(img_data.shape)
    # Guess orientations based on dimensions (excluding time if 4D)
    spatial_dimensions = img_data.shape[:-1] if img_data.ndim == 4 else img_data.shape
    # print(spatial_dimensions)
    sorted_dims = np.argsort(spatial_dimensions)  # Ascending order of dimensions
    
    # Assuming the smallest dimension is Sagittal, next is Coronal, and largest is Axial
    if len(spatial_dimensions) == 3:
        sagittal_index, coronal_index, axial_index = sorted_dims

    orientations = {}

    useful_time_points = find_highest_variance_time_points(img_data, 1) 
    # print(f"Useful time points: {useful_time_points}")
    
    for time_point in useful_time_points:

    # time_point = img_data.shape[-1] - 1

        # Extract slices for each orientation
        if img_data.ndim == 3:  # For 3D data
            orientations['Sagittal'] = img_data.swapaxes(0, sagittal_index)
            orientations['Coronal'] = img_data.swapaxes(0, coronal_index)
            orientations['Axial'] = img_data.swapaxes(0, axial_index)
        elif img_data.ndim == 4:  # For 4D data, selecting the first time point for simplicity
            orientations[f'Sagittal_time_point_{time_point}'] = img_data[:,:,:,time_point].swapaxes(0, sagittal_index)
            orientations[f'Coronal_time_point_{time_point}'] = img_data[:,:,:,time_point].swapaxes(0, coronal_index)
            orientations[f'Axial_time_point{time_point}'] = img_data[:,:,:,time_point].swapaxes(0, axial_index)

    return orientations

# %%
def get_slice_range(scan, tracer):
    """
    Determine the ideal range of slices to analyze based on the tracer used.
    """
    num_slices = scan # scan.shape[2]

    # print(f"Number of slices: {num_slices}")
    
    if tracer.lower() == 'av45' or tracer.lower() == 'pib':
        # Middle to upper slices for cortical amyloid plaques
        start_slice = int(num_slices * 0.2) # 0.4
        end_slice = int(num_slices * 0.9) # 0.7
    elif tracer.lower() == 'fdg':
        # Broad range for hypometabolism in Alzheimer's
        start_slice = int(num_slices * 0.3)
        end_slice = int(num_slices * 0.8)
    else:
        raise ValueError("Unknown tracer. Please use 'AV45', 'PIB', or 'FDG'.")
        
    return start_slice, end_slice

# %%
def extract_and_select_slices(img_data, tracer):
    """
    Extract slices for Sagittal, Coronal, and Axial orientations and select a range based on the tracer type.
    """
    
    # Extract slices for each orientation
    orientations = extract_all_slices_optimized(img_data)

    selected_axial_slices_dictionary = {}
    
    # Assuming axial orientation is of interest
    for key, value in orientations.items():
        # print(key, value.shape)
        if 'Axial' in key:
            axial_slices = orientations[key]
            # print(axial_slices.shape)
            num_axial_slices = axial_slices.shape[-1] if img_data.ndim == 4 else axial_slices.shape[2]
            
            # Get start and end slice based on tracer
            start_slice, end_slice = get_slice_range(num_axial_slices, tracer)
            
            # Select the slice range for axial orientation
            selected_axial_slices = axial_slices[:, :, start_slice:end_slice+1]

            # save in selected_axial_slices_dictionary
            selected_axial_slices_dictionary[key] = selected_axial_slices
    
    return selected_axial_slices_dictionary

# %%
def display_selected_slices(selected_axial_slices, filename, key, output_base_directory):
    """
    Display the selected axial slices.
    """
    # print(selected_axial_slices.shape)
    num_slices = selected_axial_slices.shape[2]
    cols = 5  # Number of columns in the plot grid
    rows = num_slices // cols + (1 if num_slices % cols else 0)  # Calculate rows needed

    # fig, axs = plt.subplots(rows, cols, figsize=(20, 4 * rows))
    # axs = axs.flatten()

    for i in range(num_slices):
        plt.figure(figsize=(20, 15))
        plt.imshow(selected_axial_slices[:, :, i].T, cmap='hot', origin='lower')
        plt.axis('off')
        plt.title(f'{key} Slice {i}', fontsize=16)
        plt.tight_layout()
        # plt.show()
        plt.savefig(f"{output_base_directory}/Slice_{i}_{filename}_{key}.png")
        plt.close()

# %%
def return_tracer(file_path):
    """
    Return the tracer used in the PET scan based on the file name.
    """
    file_name = os.path.basename(file_path)
    
    if 'av45' in file_name.lower():
        return 'AV45'
    elif 'pib' in file_name.lower():
        return 'PIB'
    elif 'fdg' in file_name.lower():
        return 'FDG'
    else:
        raise ValueError("Unknown tracer. Please use 'AV45', 'PIB', or 'FDG'.")

# %%
# Example usage
root_directory_path = "/Users/izzymohamed/Desktop/MLPData/PET/OASIS3/AV45"  # Update this to the directory containing your .nii.gz files


original_directory_path = root_directory_path + "/Original2"
processed_directory_path = root_directory_path + "/Processed"

os.makedirs(processed_directory_path, exist_ok=True)

# %%
# %matplotlib inline
matplotlib.use('Agg')

completed_files_count = 0  # Initialize the counter

# get length of files that end with .nii.gz
scan_length = 0
for root, dirs, files in os.walk(original_directory_path):
    for file in files:
        if file.endswith(".nii.gz"):
            scan_length += 1

# Check if file is already processed by checking if the OAS30001 and the d0000 are already in the processed directory
# If it is already processed, then skip it
# for root, dirs, files in os.walk(original_directory_path):
#     for file in files:
#         if file.endswith(".nii.gz"):
#             patientid = file.split("_")[0]
#             sessionid = file.split("_")[2]
#             for root, dirs, files in os.walk(processed_directory_path):
#                 for file1 in files:
#                     if patientid in file1 and sessionid in file1:
#                         print(f"Already processed: {patientid}_{sessionid}")



for root, dirs, files in os.walk(original_directory_path):
    for file in files:
        files.sort()
        if file.endswith(".nii.gz"):
            nii_gz_file_path = os.path.join(root, file)
            img_data = nib.load(nii_gz_file_path).get_fdata()
            result = extract_and_select_slices(img_data, return_tracer(nii_gz_file_path))
            for key, value in result.items():
                # print(key, value.shape)
                display_selected_slices(value, file, key, processed_directory_path)
            
            completed_files_count += 1  # Increment the counter after processing each file
            print(f"Completed: {completed_files_count}/{scan_length} - {file}")

print(f"Total files processed: {completed_files_count}")
# Out:
# Completed: 1/300 - sub-OAS30895_ses-d0077_acq-AV45_pet.nii.gz
# Completed: 2/300 - sub-OAS30775_ses-d2395_acq-AV45_pet.nii.gz
# Completed: 3/300 - sub-OAS31031_ses-d4072_acq-AV45_pet.nii.gz
# Completed: 4/300 - sub-OAS30959_ses-d3385_acq-AV45_pet.nii.gz
# Completed: 5/300 - sub-OAS30943_ses-d0295_acq-AV45_pet.nii.gz
# Completed: 6/300 - sub-OAS30746_ses-d0035_acq-AV45_pet.nii.gz
# Completed: 7/300 - sub-OAS30872_ses-d3097_acq-AV45_pet.nii.gz
# Completed: 8/300 - sub-OAS30561_ses-d0106_acq-AV45_pet.nii.gz
# Completed: 9/300 - sub-OAS30728_ses-d0516_acq-AV45_pet.nii.gz
# Completed: 10/300 - sub-OAS31013_ses-d0628_acq-AV45_pet.nii.gz
# Completed: 11/300 - sub-OAS31018_ses-d1208_acq-AV45_pet.nii.gz
# Completed: 12/300 - sub-OAS30673_ses-d3803_acq-AV45_pet.nii.gz
# Completed: 13/300 - sub-OAS30775_ses-d3017_acq-AV45_pet.nii.gz
# Completed: 14/300 - sub-OAS30606_ses-d2822_acq-AV45_pet.nii.gz
# Completed: 15/300 - sub-OAS30584_ses-d0096_acq-AV45_pet.nii.gz
# Completed: 16/300 - sub-OAS30680_ses-d6255_acq-AV45_pet.nii.gz
# Completed: 17/300 - sub-OAS30733_ses-d4997_acq-AV45_pet.nii.gz
# Completed: 18/300 - sub-OAS31073_ses-d3760_acq-AV45_run-04_pet.nii.gz
# Completed: 19/300 - sub-OAS30945_ses-d0155_acq-AV45_pet.nii.gz
# Completed: 20/300 - sub-OAS30690_ses-d0042_acq-AV45_pet.nii.gz
# Completed: 21/300 - sub-OAS30838_ses-d0098_acq-AV45_pet.nii.gz
# Completed: 22/300 - sub-OAS30910_ses-d1028_acq-AV45_pet.nii.gz
# Completed: 23/300 - sub-OAS30810_ses-d1351_acq-AV45_pet.nii.gz
# Completed: 24/300 - sub-OAS30750_ses-d3436_acq-AV45_pet.nii.gz
# Completed: 25/300 - sub-OAS31019_ses-d1370_acq-AV45_pet.nii.gz
# Completed: 26/300 - sub-OAS30710_ses-d3609_acq-AV45_run-04_pet.nii.gz
# Completed: 27/300 - sub-OAS30901_ses-d0155_acq-AV45_pet.nii.gz
# Completed: 28/300 - sub-OAS30934_ses-d2150_acq-AV45_pet.nii.gz
# Completed: 29/300 - sub-OAS30823_ses-d3459_acq-AV45_run-04_pet.nii.gz
# Completed: 30/300 - sub-OAS30970_ses-d0238_acq-AV45_pet.nii.gz
# Completed: 31/300 - sub-OAS31028_ses-d1285_acq-AV45_pet.nii.gz
# Completed: 32/300 - sub-OAS30670_ses-d1519_acq-AV45_run-04_pet.nii.gz
# Completed: 33/300 - sub-OAS30959_ses-d2692_acq-AV45_pet.nii.gz
# Completed: 34/300 - sub-OAS30756_ses-d1267_acq-AV45_pet.nii.gz
# Completed: 35/300 - sub-OAS30608_ses-d3984_acq-AV45_pet.nii.gz
# Completed: 36/300 - sub-OAS30764_ses-d0055_acq-AV45_pet.nii.gz
# Completed: 37/300 - sub-OAS30577_ses-d0067_acq-AV45_pet.nii.gz
# Completed: 38/300 - sub-OAS31020_ses-d1475_acq-AV45_run-05_pet.nii.gz
# Completed: 39/300 - sub-OAS30683_ses-d0051_acq-AV45_pet.nii.gz
# Completed: 40/300 - sub-OAS30875_ses-d1252_acq-AV45_pet.nii.gz
# Completed: 41/300 - sub-OAS30876_ses-d4592_acq-AV45_run-08_pet.nii.gz
# Completed: 42/300 - sub-OAS31076_ses-d1261_acq-AV45_run-04_pet.nii.gz
# Completed: 43/300 - sub-OAS30767_ses-d1285_acq-AV45_run-02_pet.nii.gz
# Completed: 44/300 - sub-OAS30756_ses-d0409_acq-AV45_pet.nii.gz
# Completed: 45/300 - sub-OAS30788_ses-d2927_acq-AV45_pet.nii.gz
# Completed: 46/300 - sub-OAS30644_ses-d0136_acq-AV45_pet.nii.gz
# Completed: 47/300 - sub-OAS30742_ses-d3766_acq-AV45_pet.nii.gz
# Completed: 48/300 - sub-OAS30601_ses-d2372_acq-AV45_pet.nii.gz
# Completed: 49/300 - sub-OAS30681_ses-d154_acq-AV45_pet.nii.gz
# Completed: 50/300 - sub-OAS30866_ses-d0640_acq-AV45_pet.nii.gz
# Completed: 51/300 - sub-OAS30842_ses-d1298_acq-AV45_run-04_pet.nii.gz
# Completed: 52/300 - sub-OAS30955_ses-d0133_acq-AV45_pet.nii.gz
# Completed: 53/300 - sub-OAS30660_ses-d4468_acq-AV45_run-08_pet.nii.gz
# Completed: 54/300 - sub-OAS31014_ses-d3555_acq-AV45_pet.nii.gz
# Completed: 55/300 - sub-OAS30594_ses-d0066_acq-AV45_pet.nii.gz
# Completed: 56/300 - sub-OAS31080_ses-d0183_acq-AV45_pet.nii.gz
# Completed: 57/300 - sub-OAS30993_ses-d0920_acq-AV45_pet.nii.gz
# Completed: 58/300 - sub-OAS30589_ses-d3191_acq-AV45_pet.nii.gz
# Completed: 59/300 - sub-OAS31048_ses-d3195_acq-AV45_pet.nii.gz
# Completed: 60/300 - sub-OAS30978_ses-d59_acq-AV45_pet.nii.gz
# Completed: 61/300 - sub-OAS30907_ses-d3359_acq-AV45_pet.nii.gz
# Completed: 62/300 - sub-OAS30768_ses-d2337_acq-AV45_pet.nii.gz
# Completed: 63/300 - sub-OAS30862_ses-d3654_acq-AV45_pet.nii.gz
# Completed: 64/300 - sub-OAS30568_ses-d2326_acq-AV45_pet.nii.gz
# Completed: 65/300 - sub-OAS30786_ses-d4891_acq-AV45_run-02_pet.nii.gz
# Completed: 66/300 - sub-OAS30858_ses-d2100_acq-AV45_pet.nii.gz
# Completed: 67/300 - sub-OAS31018_ses-d0045_acq-AV45_pet.nii.gz
# Completed: 68/300 - sub-OAS30647_ses-d1286_acq-AV45_pet.nii.gz
# Completed: 69/300 - sub-OAS31062_ses-d0071_acq-AV45_pet.nii.gz
# Completed: 70/300 - sub-OAS30896_ses-d3528_acq-AV45_pet.nii.gz
# Completed: 71/300 - sub-OAS30742_ses-d4551_acq-AV45_pet.nii.gz
# Completed: 72/300 - sub-OAS30950_ses-d0063_acq-AV45_pet.nii.gz
# Completed: 73/300 - sub-OAS30822_ses-d3227_acq-AV45_run-04_pet.nii.gz
# Completed: 74/300 - sub-OAS30921_ses-d2468_acq-AV45_pet.nii.gz
# Completed: 75/300 - sub-OAS30866_ses-d94_acq-AV45_pet.nii.gz
# Completed: 76/300 - sub-OAS31028_ses-d69_acq-AV45_pet.nii.gz
# Completed: 77/300 - sub-OAS30877_ses-d2308_acq-AV45_run-08_pet.nii.gz
# Completed: 78/300 - sub-OAS30706_ses-d1228_acq-AV45_run-04_pet.nii.gz
# Completed: 79/300 - sub-OAS30668_ses-d3574_acq-AV45_pet.nii.gz
# Completed: 80/300 - sub-OAS30603_ses-d2253_acq-AV45_pet.nii.gz
# Completed: 81/300 - sub-OAS31086_ses-d0065_acq-AV45_pet.nii.gz
# Completed: 82/300 - sub-OAS30992_ses-d0470_acq-AV45_pet.nii.gz
# Completed: 83/300 - sub-OAS30937_ses-d4779_acq-AV45_pet.nii.gz
# Completed: 84/300 - sub-OAS30756_ses-d0022_acq-AV45_pet.nii.gz
# Completed: 85/300 - sub-OAS30803_ses-d4473_acq-AV45_pet.nii.gz
# Completed: 86/300 - sub-OAS30769_ses-d3319_acq-AV45_run-06_pet.nii.gz
# Completed: 87/300 - sub-OAS31015_ses-d0222_acq-AV45_pet.nii.gz
# Completed: 88/300 - sub-OAS30751_ses-d0063_acq-AV45_pet.nii.gz
# Completed: 89/300 - sub-OAS30809_ses-d0252_acq-AV45_pet.nii.gz
# Completed: 90/300 - sub-OAS30917_ses-d1196_acq-AV45_run-04_pet.nii.gz
# Completed: 91/300 - sub-OAS30638_ses-d72_acq-AV45_pet.nii.gz
# Completed: 92/300 - sub-OAS30974_ses-d0901_acq-AV45_pet.nii.gz
# Completed: 93/300 - sub-OAS30861_ses-d1702_acq-AV45_pet.nii.gz
# Completed: 94/300 - sub-OAS31022_ses-d0089_acq-AV45_pet.nii.gz
# Completed: 95/300 - sub-OAS30863_ses-d4148_acq-AV45_pet.nii.gz
# Completed: 96/300 - sub-OAS31013_ses-d1656_acq-AV45_run-04_pet.nii.gz
# Completed: 97/300 - sub-OAS30731_ses-d3375_acq-AV45_run-04_pet.nii.gz
# Completed: 98/300 - sub-OAS30659_ses-d2760_acq-AV45_run-04_pet.nii.gz
# Completed: 99/300 - sub-OAS31039_ses-d1184_acq-AV45_pet.nii.gz
# Completed: 100/300 - sub-OAS30590_ses-d85_acq-AV45_pet.nii.gz
# Completed: 101/300 - sub-OAS30959_ses-d4631_acq-AV45_run-06_pet.nii.gz
# Completed: 102/300 - sub-OAS31071_ses-d0978_acq-AV45_run-04_pet.nii.gz
# Completed: 103/300 - sub-OAS30819_ses-d0572_acq-AV45_pet.nii.gz
# Completed: 104/300 - sub-OAS30818_ses-d1720_acq-AV45_pet.nii.gz
# Completed: 105/300 - sub-OAS30978_ses-d2117_acq-AV45_run-04_pet.nii.gz
# Completed: 106/300 - sub-OAS31059_ses-d4501_acq-AV45_run-04_pet.nii.gz
# Completed: 107/300 - sub-OAS30670_ses-d0083_acq-AV45_pet.nii.gz
# Completed: 108/300 - sub-OAS30777_ses-d4740_acq-AV45_pet.nii.gz
# Completed: 109/300 - sub-OAS30659_ses-d1668_acq-AV45_pet.nii.gz
# Completed: 110/300 - sub-OAS30822_ses-d2022_acq-AV45_pet.nii.gz
# Completed: 111/300 - sub-OAS30770_ses-d1210_acq-AV45_pet.nii.gz
# Completed: 112/300 - sub-OAS30938_ses-d1242_acq-AV45_pet.nii.gz
# Completed: 113/300 - sub-OAS30597_ses-d3137_acq-AV45_pet.nii.gz
# Completed: 114/300 - sub-OAS31042_ses-d3618_acq-AV45_pet.nii.gz
# Completed: 115/300 - sub-OAS31084_ses-d2319_acq-AV45_pet.nii.gz
# Completed: 116/300 - sub-OAS30667_ses-d115_acq-AV45_pet.nii.gz
# Completed: 117/300 - sub-OAS30819_ses-d1776_acq-AV45_run-04_pet.nii.gz
# Completed: 118/300 - sub-OAS31076_ses-d71_acq-AV45_pet.nii.gz
# Completed: 119/300 - sub-OAS30939_ses-d1968_acq-AV45_pet.nii.gz
# Completed: 120/300 - sub-OAS31053_ses-d0057_acq-AV45_pet.nii.gz
# Completed: 121/300 - sub-OAS30884_ses-d4499_acq-AV45_pet.nii.gz
# Completed: 122/300 - sub-OAS30586_ses-d0749_acq-AV45_pet.nii.gz
# Completed: 123/300 - sub-OAS30725_ses-d2456_acq-AV45_pet.nii.gz
# Completed: 124/300 - sub-OAS31037_ses-d6061_acq-AV45_pet.nii.gz
# Completed: 125/300 - sub-OAS30922_ses-d0058_acq-AV45_pet.nii.gz
# Completed: 126/300 - sub-OAS30813_ses-d1156_acq-AV45_run-04_pet.nii.gz
# Completed: 127/300 - sub-OAS30820_ses-d1903_acq-AV45_run-04_pet.nii.gz
# Completed: 128/300 - sub-OAS30637_ses-d1185_acq-AV45_run-04_pet.nii.gz
# Completed: 129/300 - sub-OAS30762_ses-d1002_acq-AV45_pet.nii.gz
# Completed: 130/300 - sub-OAS30676_ses-d3567_acq-AV45_pet.nii.gz
# Completed: 131/300 - sub-OAS30824_ses-d0077_acq-AV45_pet.nii.gz
# Completed: 132/300 - sub-OAS30759_ses-d0063_acq-AV45_pet.nii.gz
# Completed: 133/300 - sub-OAS31010_ses-d0086_acq-AV45_pet.nii.gz
# Completed: 134/300 - sub-OAS31048_ses-d2385_acq-AV45_pet.nii.gz
# Completed: 135/300 - sub-OAS30588_ses-d4795_acq-AV45_run-04_pet.nii.gz
# Completed: 136/300 - sub-OAS30881_ses-d3163_acq-AV45_pet.nii.gz
# Completed: 137/300 - sub-OAS30867_ses-d4407_acq-AV45_pet.nii.gz
# Completed: 138/300 - sub-OAS30723_ses-d2568_acq-AV45_pet.nii.gz
# Completed: 139/300 - sub-OAS30632_ses-d1800_acq-AV45_pet.nii.gz
# Completed: 140/300 - sub-OAS30567_ses-d0040_acq-AV45_pet.nii.gz
# Completed: 141/300 - sub-OAS30832_ses-d3848_acq-AV45_run-08_pet.nii.gz
# Completed: 142/300 - sub-OAS30988_ses-d0033_acq-AV45_pet.nii.gz
# Completed: 143/300 - sub-OAS30996_ses-d4705_acq-AV45_pet.nii.gz
# Completed: 144/300 - sub-OAS30580_ses-d1531_acq-AV45_pet.nii.gz
# Completed: 145/300 - sub-OAS30832_ses-d2369_acq-AV45_pet.nii.gz
# Completed: 146/300 - sub-OAS30648_ses-d0127_acq-AV45_pet.nii.gz
# Completed: 147/300 - sub-OAS30926_ses-d1520_acq-AV45_pet.nii.gz
# Completed: 148/300 - sub-OAS30701_ses-d3293_acq-AV45_run-04_pet.nii.gz
# Completed: 149/300 - sub-OAS30579_ses-d2400_acq-AV45_pet.nii.gz
# Completed: 150/300 - sub-OAS30908_ses-d3517_acq-AV45_run-04_pet.nii.gz
# Completed: 151/300 - sub-OAS30676_ses-d4132_acq-AV45_pet.nii.gz
# Completed: 152/300 - sub-OAS30667_ses-d0502_acq-AV45_pet.nii.gz
# Completed: 153/300 - sub-OAS30568_ses-d1284_acq-AV45_pet.nii.gz
# Completed: 154/300 - sub-OAS30981_ses-d74_acq-AV45_pet.nii.gz
# Completed: 155/300 - sub-OAS30620_ses-d2211_acq-AV45_pet.nii.gz
# Completed: 156/300 - sub-OAS30919_ses-d4506_acq-AV45_run-02_pet.nii.gz
# Completed: 157/300 - sub-OAS30679_ses-d0091_acq-AV45_pet.nii.gz
# Completed: 158/300 - sub-OAS30818_ses-d3524_acq-AV45_run-04_pet.nii.gz
# Completed: 159/300 - sub-OAS30792_ses-d3410_acq-AV45_run-04_pet.nii.gz
# Completed: 160/300 - sub-OAS30688_ses-d3465_acq-AV45_pet.nii.gz
# Completed: 161/300 - sub-OAS30656_ses-d2737_acq-AV45_pet.nii.gz
# Completed: 162/300 - sub-OAS30757_ses-d3882_acq-AV45_run-04_pet.nii.gz
# Completed: 163/300 - sub-OAS30841_ses-d3499_acq-AV45_pet.nii.gz
# Completed: 164/300 - sub-OAS30776_ses-d4024_acq-AV45_pet.nii.gz
# Completed: 165/300 - sub-OAS30708_ses-d0071_acq-AV45_pet.nii.gz
# Completed: 166/300 - sub-OAS30592_ses-d0087_acq-AV45_pet.nii.gz
# Completed: 167/300 - sub-OAS30777_ses-d5615_acq-AV45_run-06_pet.nii.gz
# Completed: 168/300 - sub-OAS30961_ses-d0062_acq-AV45_pet.nii.gz
# Completed: 169/300 - sub-OAS30979_ses-d0435_acq-AV45_pet.nii.gz
# Completed: 170/300 - sub-OAS30706_ses-d0060_acq-AV45_pet.nii.gz
# Completed: 171/300 - sub-OAS31064_ses-d3450_acq-AV45_pet.nii.gz
# Completed: 172/300 - sub-OAS30808_ses-d3453_acq-AV45_pet.nii.gz
# Completed: 173/300 - sub-OAS30960_ses-d4513_acq-AV45_pet.nii.gz
# Completed: 174/300 - sub-OAS30933_ses-d3460_acq-AV45_run-08_pet.nii.gz
# Completed: 175/300 - sub-OAS30664_ses-d3557_acq-AV45_pet.nii.gz
# Completed: 176/300 - sub-OAS31020_ses-d0084_acq-AV45_pet.nii.gz
# Completed: 177/300 - sub-OAS30823_ses-d2722_acq-AV45_pet.nii.gz
# Completed: 178/300 - sub-OAS30573_ses-d0515_acq-AV45_pet.nii.gz
# Completed: 179/300 - sub-OAS30637_ses-d0079_acq-AV45_pet.nii.gz
# Completed: 180/300 - sub-OAS30643_ses-d2334_acq-AV45_pet.nii.gz
# Completed: 181/300 - sub-OAS30914_ses-d0108_acq-AV45_pet.nii.gz
# Completed: 182/300 - sub-OAS30990_ses-d1360_acq-AV45_pet.nii.gz
# Completed: 183/300 - sub-OAS30818_ses-d1228_acq-AV45_pet.nii.gz
# Completed: 184/300 - sub-OAS30816_ses-d4576_acq-AV45_run-04_pet.nii.gz
# Completed: 185/300 - sub-OAS30748_ses-d3268_acq-AV45_pet.nii.gz
# Completed: 186/300 - sub-OAS30798_ses-d0078_acq-AV45_pet.nii.gz
# Completed: 187/300 - sub-OAS30683_ses-d0528_acq-AV45_pet.nii.gz
# Completed: 188/300 - sub-OAS30685_ses-d1552_acq-AV45_pet.nii.gz
# Completed: 189/300 - sub-OAS30643_ses-d3279_acq-AV45_run-03_pet.nii.gz
# Completed: 190/300 - sub-OAS30599_ses-d0121_acq-AV45_pet.nii.gz
# Completed: 191/300 - sub-OAS30695_ses-d0104_acq-AV45_pet.nii.gz
# Completed: 192/300 - sub-OAS30572_ses-d64_acq-AV45_pet.nii.gz
# Completed: 193/300 - sub-OAS31001_ses-d4543_acq-AV45_run-04_pet.nii.gz
# Completed: 194/300 - sub-OAS30854_ses-d3380_acq-AV45_run-08_pet.nii.gz
# Completed: 195/300 - sub-OAS30779_ses-d0065_acq-AV45_pet.nii.gz
# Completed: 196/300 - sub-OAS31023_ses-d3561_acq-AV45_pet.nii.gz
# Completed: 197/300 - sub-OAS30749_ses-d1996_acq-AV45_pet.nii.gz
# Completed: 198/300 - sub-OAS30917_ses-d0053_acq-AV45_pet.nii.gz
# Completed: 199/300 - sub-OAS30834_ses-d0098_acq-AV45_pet.nii.gz
# Completed: 200/300 - sub-OAS30821_ses-d0068_acq-AV45_pet.nii.gz
# Completed: 201/300 - sub-OAS31070_ses-d0084_acq-AV45_pet.nii.gz
# Completed: 202/300 - sub-OAS30793_ses-d1343_acq-AV45_pet.nii.gz
# Completed: 203/300 - sub-OAS30571_ses-d3528_acq-AV45_run-04_pet.nii.gz
# Completed: 204/300 - sub-OAS30966_ses-d3381_acq-AV45_pet.nii.gz
# Completed: 205/300 - sub-OAS30812_ses-d0055_acq-AV45_pet.nii.gz
# Completed: 206/300 - sub-OAS31031_ses-d5046_acq-AV45_run-04_pet.nii.gz
# Completed: 207/300 - sub-OAS30857_ses-d1263_acq-AV45_pet.nii.gz
# Completed: 208/300 - sub-OAS30843_ses-d0236_acq-AV45_pet.nii.gz
# Completed: 209/300 - sub-OAS30671_ses-d3613_acq-AV45_pet.nii.gz
# Completed: 210/300 - sub-OAS30759_ses-d1442_acq-AV45_run-04_pet.nii.gz
# Completed: 211/300 - sub-OAS30842_ses-d0526_acq-AV45_pet.nii.gz
# Completed: 212/300 - sub-OAS30722_ses-d1162_acq-AV45_pet.nii.gz
# Completed: 213/300 - sub-OAS30852_ses-d6963_acq-AV45_pet.nii.gz
# Completed: 214/300 - sub-OAS30585_ses-d0065_acq-AV45_pet.nii.gz
# Completed: 215/300 - sub-OAS31065_ses-d0044_acq-AV45_pet.nii.gz
# Completed: 216/300 - sub-OAS30948_ses-d0076_acq-AV45_pet.nii.gz
# Completed: 217/300 - sub-OAS31023_ses-d2441_acq-AV45_pet.nii.gz
# Completed: 218/300 - sub-OAS30667_ses-d0888_acq-AV45_pet.nii.gz
# Completed: 219/300 - sub-OAS30558_ses-d4493_acq-AV45_pet.nii.gz
# Completed: 220/300 - sub-OAS30739_ses-d0051_acq-AV45_pet.nii.gz
# Completed: 221/300 - sub-OAS30721_ses-d0062_acq-AV45_pet.nii.gz
# Completed: 222/300 - sub-OAS30827_ses-d1875_acq-AV45_pet.nii.gz
# Completed: 223/300 - sub-OAS31039_ses-d2184_acq-AV45_run-04_pet.nii.gz
# Completed: 224/300 - sub-OAS30887_ses-d1407_acq-AV45_pet.nii.gz
# Completed: 225/300 - sub-OAS30986_ses-d4711_acq-AV45_run-06_pet.nii.gz
# Completed: 226/300 - sub-OAS31012_ses-d4024_acq-AV45_pet.nii.gz
# Completed: 227/300 - sub-OAS30666_ses-d0155_acq-AV45_pet.nii.gz
# Completed: 228/300 - sub-OAS30964_ses-d3870_acq-AV45_pet.nii.gz
# Completed: 229/300 - sub-OAS31083_ses-d3346_acq-AV45_run-06_pet.nii.gz
# Completed: 230/300 - sub-OAS30636_ses-d1199_acq-AV45_run-04_pet.nii.gz
# Completed: 231/300 - sub-OAS30607_ses-d0117_acq-AV45_pet.nii.gz
# Completed: 232/300 - sub-OAS30754_ses-d2462_acq-AV45_pet.nii.gz
# Completed: 233/300 - sub-OAS30905_ses-d2331_acq-AV45_pet.nii.gz
# Completed: 234/300 - sub-OAS30735_ses-d3515_acq-AV45_pet.nii.gz
# Completed: 235/300 - sub-OAS30663_ses-d0051_acq-AV45_pet.nii.gz
# Completed: 236/300 - sub-OAS30767_ses-d948_acq-AV45_pet.nii.gz
# Completed: 237/300 - sub-OAS31068_ses-d3484_acq-AV45_pet.nii.gz
# Completed: 238/300 - sub-OAS30587_ses-d4511_acq-AV45_pet.nii.gz
# Completed: 239/300 - sub-OAS30794_ses-d5548_acq-AV45_pet.nii.gz
# Completed: 240/300 - sub-OAS31041_ses-d1426_acq-AV45_pet.nii.gz
# Completed: 241/300 - sub-OAS30845_ses-d1266_acq-AV45_pet.nii.gz
# Completed: 242/300 - sub-OAS31011_ses-d0089_acq-AV45_pet.nii.gz
# Completed: 243/300 - sub-OAS30651_ses-d3150_acq-AV45_run-04_pet.nii.gz
# Completed: 244/300 - sub-OAS30746_ses-d1210_acq-AV45_run-04_pet.nii.gz
# Completed: 245/300 - sub-OAS30601_ses-d1146_acq-AV45_pet.nii.gz
# Completed: 246/300 - sub-OAS30938_ses-d249_acq-AV45_pet.nii.gz
# Completed: 247/300 - sub-OAS30727_ses-d1208_acq-AV45_pet.nii.gz
# Completed: 248/300 - sub-OAS31000_ses-d0072_acq-AV45_pet.nii.gz
# Completed: 249/300 - sub-OAS30927_ses-d1180_acq-AV45_run-06_pet.nii.gz
# Completed: 250/300 - sub-OAS30739_ses-d1394_acq-AV45_run-02_pet.nii.gz
# Completed: 251/300 - sub-OAS31021_ses-d1318_acq-AV45_pet.nii.gz
# Completed: 252/300 - sub-OAS30580_ses-d2664_acq-AV45_run-04_pet.nii.gz
# Completed: 253/300 - sub-OAS30586_ses-d1149_acq-AV45_pet.nii.gz
# Completed: 254/300 - sub-OAS30635_ses-d1533_acq-AV45_pet.nii.gz
# Completed: 255/300 - sub-OAS30597_ses-d4209_acq-AV45_run-04_pet.nii.gz
# Completed: 256/300 - sub-OAS30900_ses-d1058_acq-AV45_run-04_pet.nii.gz
# Completed: 257/300 - sub-OAS31056_ses-d1912_acq-AV45_pet.nii.gz
# Completed: 258/300 - sub-OAS30763_ses-d0112_acq-AV45_pet.nii.gz
# Completed: 259/300 - sub-OAS30715_ses-d61_acq-AV45_pet.nii.gz
# Completed: 260/300 - sub-OAS30813_ses-d0138_acq-AV45_pet.nii.gz
# Completed: 261/300 - sub-OAS30755_ses-d3410_acq-AV45_run-08_pet.nii.gz
# Completed: 262/300 - sub-OAS30691_ses-d0056_acq-AV45_pet.nii.gz
# Completed: 263/300 - sub-OAS30711_ses-d3480_acq-AV45_pet.nii.gz
# Completed: 264/300 - sub-OAS30574_ses-d1917_acq-AV45_pet.nii.gz
# Completed: 265/300 - sub-OAS30625_ses-d2232_acq-AV45_run-02_pet.nii.gz
# Completed: 266/300 - sub-OAS30673_ses-d2417_acq-AV45_pet.nii.gz
# Completed: 267/300 - sub-OAS31005_ses-d1649_acq-AV45_pet.nii.gz
# Completed: 268/300 - sub-OAS30789_ses-d1604_acq-AV45_pet.nii.gz
# Completed: 269/300 - sub-OAS30807_ses-d0472_acq-AV45_pet.nii.gz
# Completed: 270/300 - sub-OAS30978_ses-d0425_acq-AV45_pet.nii.gz
# Completed: 271/300 - sub-OAS30729_ses-d6253_acq-AV45_pet.nii.gz
# Completed: 272/300 - sub-OAS30869_ses-d2092_acq-AV45_pet.nii.gz
# Completed: 273/300 - sub-OAS30818_ses-d2089_acq-AV45_pet.nii.gz
# Completed: 274/300 - sub-OAS31071_ses-d0068_acq-AV45_pet.nii.gz
# Completed: 275/300 - sub-OAS30846_ses-d1136_acq-AV45_run-06_pet.nii.gz
# Completed: 276/300 - sub-OAS30572_ses-d1156_acq-AV45_pet.nii.gz
# Completed: 277/300 - sub-OAS31064_ses-d3883_acq-AV45_pet.nii.gz
# Completed: 278/300 - sub-OAS30996_ses-d5818_acq-AV45_run-08_pet.nii.gz
# Completed: 279/300 - sub-OAS30921_ses-d3232_acq-AV45_pet.nii.gz
# Completed: 280/300 - sub-OAS30913_ses-d2007_acq-AV45_pet.nii.gz
# Completed: 281/300 - sub-OAS30973_ses-d1318_acq-AV45_run-08_pet.nii.gz
# Completed: 282/300 - sub-OAS30997_ses-d1356_acq-AV45_pet.nii.gz
# Completed: 283/300 - sub-OAS30781_ses-d0971_acq-AV45_pet.nii.gz
# Completed: 284/300 - sub-OAS30618_ses-d0059_acq-AV45_pet.nii.gz
# Completed: 285/300 - sub-OAS31013_ses-d67_acq-AV45_pet.nii.gz
# Completed: 286/300 - sub-OAS30742_ses-d3401_acq-AV45_pet.nii.gz
# Completed: 287/300 - sub-OAS30839_ses-d1477_acq-AV45_pet.nii.gz
# Completed: 288/300 - sub-OAS30750_ses-d2350_acq-AV45_pet.nii.gz
# Completed: 289/300 - sub-OAS30769_ses-d1554_acq-AV45_pet.nii.gz
# Completed: 290/300 - sub-OAS31020_ses-d0651_acq-AV45_pet.nii.gz
# Completed: 291/300 - sub-OAS30562_ses-d3383_acq-AV45_pet.nii.gz
# Completed: 292/300 - sub-OAS30766_ses-d0147_acq-AV45_pet.nii.gz
# Completed: 293/300 - sub-OAS30982_ses-d1708_acq-AV45_pet.nii.gz
# Completed: 294/300 - sub-OAS30927_ses-d0145_acq-AV45_pet.nii.gz
# Completed: 295/300 - sub-OAS30720_ses-d4213_acq-AV45_pet.nii.gz
# Completed: 296/300 - sub-OAS31054_ses-d2787_acq-AV45_pet.nii.gz
# Completed: 297/300 - sub-OAS31072_ses-d4621_acq-AV45_pet.nii.gz
# Completed: 298/300 - sub-OAS30715_ses-d1230_acq-AV45_pet.nii.gz
# Completed: 299/300 - sub-OAS30953_ses-d0103_acq-AV45_pet.nii.gz
# Completed: 300/300 - sub-OAS30869_ses-d1706_acq-AV45_pet.nii.gz
# Total files processed: 300

# %%
# print names of files in the processed directory 
# print in form of patientid_AV45_sessionid
list1 = []
for root, dirs, files in os.walk(processed_directory_path, topdown=True):
    # go through all files in the directory sorted
    
    for file in files:
        if file.endswith(".png") and "Slice_0" in file:
            patientid = file.split("_")[2].split("-")[1]
            sessionid = file.split("_")[3].split("-")[1]
            list1.append(f"{patientid}_AV45_{sessionid}")
            print(f"{patientid}_AV45_{sessionid}")
# Out:
# OAS30843_AV45_d0236
# OAS30632_AV45_d1800
# OAS30531_AV45_d1347
# OAS30283_AV45_d2660
# OAS30917_AV45_d1196
# OAS30434_AV45_d0054
# OAS30296_AV45_d0069
# OAS30759_AV45_d1442
# OAS30262_AV45_d839
# OAS31376_AV45_d1213
# OAS31213_AV45_d0114
# OAS31020_AV45_d1475
# OAS30367_AV45_d4337
# OAS30139_AV45_d1702
# OAS31267_AV45_d0090
# OAS30206_AV45_d3024
# OAS31096_AV45_d1308
# OAS31307_AV45_d0113
# OAS30026_AV45_d0696
# OAS31148_AV45_d1290
# OAS30635_AV45_d1533
# OAS31019_AV45_d1370
# OAS31392_AV45_d0144
# OAS30293_AV45_d1221
# OAS30038_AV45_d5769
# OAS31114_AV45_d2658
# OAS30173_AV45_d3841
# OAS30324_AV45_d2433
# OAS30062_AV45_d4447
# OAS31073_AV45_d3760
# OAS31293_AV45_d0084
# OAS30926_AV45_d1520
# OAS30748_AV45_d3268
# OAS31048_AV45_d3195
# OAS30764_AV45_d0055
# OAS30776_AV45_d4024
# OAS31473_AV45_d0136
# OAS30005_AV45_d2384
# OAS30643_AV45_d2334
# OAS31224_AV45_d0116
# OAS31071_AV45_d0068
# OAS31386_AV45_d0202
# OAS30568_AV45_d2326
# OAS31300_AV45_d0212
# OAS30024_AV45_d0084
# OAS31353_AV45_d0117
# OAS30767_AV45_d948
# OAS30322_AV45_d5194
# OAS31295_AV45_d0120
# OAS30584_AV45_d0096
# OAS30746_AV45_d1210
# OAS30770_AV45_d1210
# OAS31247_AV45_d0110
# OAS30096_AV45_d2948
# OAS31255_AV45_d0100
# OAS31248_AV45_d0239
# OAS30462_AV45_d1232
# OAS30742_AV45_d3401
# OAS30522_AV45_d0103
# OAS30755_AV45_d3410
# OAS30927_AV45_d0145
# OAS31090_AV45_d3565
# OAS30561_AV45_d0106
# OAS30599_AV45_d0121
# OAS30586_AV45_d1149
# OAS30842_AV45_d1298
# OAS30990_AV45_d1360
# OAS30818_AV45_d1228
# OAS30589_AV45_d3191
# OAS30312_AV45_d0068
# OAS31309_AV45_d0173
# OAS30966_AV45_d3381
